# %% [markdown]
# # Backtest: validation on historical data
#
# <a href="https://mybinder.org/v2/gh/tinkoff-ai/etna/master?filepath=examples/backtest.ipynb">
#     <img src="https://mybinder.org/badge_logo.svg"  align='left'>
# </a>

# %% [markdown]
# This notebook contains the simple examples of time series validation using backtest module of ETNA library.
#
# **Table of Contents**
#
# * [What is backtest and how it works](#chapter1)
# * [How to run a validation](#chapter2)
# * [Backtest with FoldMask](#chapter3)
# * [Validation visualisation](#chapter4)
# * [Metrics visualisation](#chapter5)

# %%
import sys
import os

sys.path.append(os.path.join(sys.path[0], '..'))

# print(*sys.path, sep='\n')

# %%
import pandas as pd
import matplotlib.pyplot as plt

from etna.datasets.tsdataset import TSDataset
from etna.metrics import MAE
from etna.metrics import MSE
from etna.metrics import SMAPE
from etna.pipeline import Pipeline
from etna.models import ProphetModel
from etna.analysis import plot_backtest
from etna.transforms import TimeSeriesImputerTransform

from utils import load_df
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS
#
# libgomp: Invalid value for environment variable OMP_NUM_THREADS
# /home/user/conda/envs/algo/lib/python3.10/site-packages/numba/core/config.py:197: RuntimeWarning: Environment variable 'NUMBA_NUM_THREADS' is defined but its associated value '' could not be parsed.
# The parse failed with exception: invalid literal for int() with base 10: ''.
#   warnings.warn(f"Environment variable '{name}' is defined but "

# %% [markdown]
# ### 1. What is backtest and how it works <a class="anchor" id="chapter1"></a>

# %% [markdown]
# Backtest is a predictions and validation pipeline build on historical data to make a legitimate retrotest of your model.
#
# <b>How does it work?</b>
#
# When constructing a forecast using Models and further evaluating the prediction metrics, we measure the quality at one time interval, designated as test.
#
# Backtest allows you to simulate how the model would work in the past:
#
# * selects a period of time in the past
#
# * builds a model using the selected interval as a training sample
#
# * predicts the value on the test interval and calculates metrics.
#
# The image shows a plot of the backtest pipeline with `n_folds = 3`.

# %%
PERIODS = {
    "day": 'D',
    "week": 'W',
    'month': "M",
    'year': "Y"}

# %% [markdown]
# Below we will call a fold the train + test pair, for which training and forecasting is performed.

# %%
candles = load_df(period='10m')
#pd.read_csv("./data/example_dataset.csv")
candles["timestamp"] = candles['begin']
candles['segment'] = candles['timestamp'].dt.to_period(PERIODS['month'])
candles['target'] = candles['close']

candles.drop(columns=['begin', 'end'], inplace=True)
# candles.to_csv('candles_daily.csv')
candles
# Out:
#         open   close    high     low        value     volume  \
# 0     264.89  264.89  264.89  264.89   68129708.0   257200.0
# 1     264.90  264.25  265.18  263.80  573080891.3  2167670.0
# 2     264.26  264.22  264.95  263.90  441929827.4  1671130.0
# 3     264.22  264.23  264.45  264.05  187603360.0   710040.0
# 4     264.23  264.23  264.58  264.20  217393400.8   822500.0
# ...      ...     ...     ...     ...          ...        ...
# 3634  264.94  264.92  265.00  264.86   20944365.3    79050.0
# 3635  264.94  264.94  264.98  264.89    5680326.2    21440.0
# 3636  264.94  264.85  264.94  264.82   14379529.2    54290.0
# 3637  264.85  264.83  264.85  264.80    7592342.0    28670.0
# 3638  264.84  264.88  264.89  264.68   20743984.2    78340.0
#
#                timestamp  segment  target
# 0    2023-10-10 09:50:00  2023-10  264.89
# 1    2023-10-10 10:00:00  2023-10  264.25
# 2    2023-10-10 10:10:00  2023-10  264.22
# 3    2023-10-10 10:20:00  2023-10  264.23
# 4    2023-10-10 10:30:00  2023-10  264.23
# ...                  ...      ...     ...
# 3634 2023-12-08 20:50:00  2023-12  264.92
# 3635 2023-12-08 21:00:00  2023-12  264.94
# 3636 2023-12-08 21:10:00  2023-12  264.85
# 3637 2023-12-08 21:20:00  2023-12  264.83
# 3638 2023-12-08 21:30:00  2023-12  264.88
#
# [3639 rows x 9 columns]

# %%
candles['volume'].plot()
# Out:
# <Axes: >

# %% [markdown]
# Our library works with the special data structure TSDataset. So, before starting the EDA, we need to convert the classical DataFrame to TSDataset.

# %%
df = TSDataset.to_dataset(candles)
ts = TSDataset(df, freq="W")
# ts.df.dropna(inplace=True)
# ts.to_pandas().to_csv('aboba.xlsx')
# Out:
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is None, you set W
#   warnings.warn(

# %%
ts
# Out:
# segment             2023-10                                   2023-11       \
# feature               close high low open target value volume   close high
# timestamp
# 2023-10-15 09:50:00     NaN  NaN NaN  NaN    NaN   NaN    NaN     NaN  NaN
# 2023-10-22 09:50:00     NaN  NaN NaN  NaN    NaN   NaN    NaN     NaN  NaN
# 2023-10-29 09:50:00     NaN  NaN NaN  NaN    NaN   NaN    NaN     NaN  NaN
# 2023-11-05 09:50:00     NaN  NaN NaN  NaN    NaN   NaN    NaN     NaN  NaN
# 2023-11-12 09:50:00     NaN  NaN NaN  NaN    NaN   NaN    NaN     NaN  NaN
# 2023-11-19 09:50:00     NaN  NaN NaN  NaN    NaN   NaN    NaN     NaN  NaN
# 2023-11-26 09:50:00     NaN  NaN NaN  NaN    NaN   NaN    NaN     NaN  NaN
# 2023-12-03 09:50:00     NaN  NaN NaN  NaN    NaN   NaN    NaN     NaN  NaN
#
# segment                  ...                     2023-12                       \
# feature             low  ... target value volume   close high low open target
# timestamp                ...
# 2023-10-15 09:50:00 NaN  ...    NaN   NaN    NaN     NaN  NaN NaN  NaN    NaN
# 2023-10-22 09:50:00 NaN  ...    NaN   NaN    NaN     NaN  NaN NaN  NaN    NaN
# 2023-10-29 09:50:00 NaN  ...    NaN   NaN    NaN     NaN  NaN NaN  NaN    NaN
# 2023-11-05 09:50:00 NaN  ...    NaN   NaN    NaN     NaN  NaN NaN  NaN    NaN
# 2023-11-12 09:50:00 NaN  ...    NaN   NaN    NaN     NaN  NaN NaN  NaN    NaN
# 2023-11-19 09:50:00 NaN  ...    NaN   NaN    NaN     NaN  NaN NaN  NaN    NaN
# 2023-11-26 09:50:00 NaN  ...    NaN   NaN    NaN     NaN  NaN NaN  NaN    NaN
# 2023-12-03 09:50:00 NaN  ...    NaN   NaN    NaN     NaN  NaN NaN  NaN    NaN
#
# segment
# feature             value volume
# timestamp
# 2023-10-15 09:50:00   NaN    NaN
# 2023-10-22 09:50:00   NaN    NaN
# 2023-10-29 09:50:00   NaN    NaN
# 2023-11-05 09:50:00   NaN    NaN
# 2023-11-12 09:50:00   NaN    NaN
# 2023-11-19 09:50:00   NaN    NaN
# 2023-11-26 09:50:00   NaN    NaN
# 2023-12-03 09:50:00   NaN    NaN
#
# [8 rows x 21 columns]

# %%
ts.plot()

# %%
ts.segments
# Out:
# ['2023-10-10',
#  '2023-10-11',
#  '2023-10-12',
#  '2023-10-13',
#  '2023-10-16',
#  '2023-10-17',
#  '2023-10-18',
#  '2023-10-19',
#  '2023-10-20',
#  '2023-10-23',
#  '2023-10-24',
#  '2023-10-25',
#  '2023-10-26',
#  '2023-10-27',
#  '2023-10-30',
#  '2023-10-31',
#  '2023-11-01',
#  '2023-11-02',
#  '2023-11-03',
#  '2023-11-06',
#  '2023-11-07',
#  '2023-11-08',
#  '2023-11-09',
#  '2023-11-10',
#  '2023-11-13',
#  '2023-11-14',
#  '2023-11-15',
#  '2023-11-16',
#  '2023-11-17',
#  '2023-11-20',
#  '2023-11-21',
#  '2023-11-22',
#  '2023-11-23',
#  '2023-11-24',
#  '2023-11-27',
#  '2023-11-28',
#  '2023-11-29',
#  '2023-11-30',
#  '2023-12-01',
#  '2023-12-04',
#  '2023-12-05',
#  '2023-12-06',
#  '2023-12-07',
#  '2023-12-08']

# %% [markdown]
# #### Let's get a look on series

# %%
imputer = TimeSeriesImputerTransform(strategy='running_mean')
imputer.fit_transform(ts[ts.segments[0]]).plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_131715/3480829772.py in ?()
#       1 imputer = TimeSeriesImputerTransform(strategy='running_mean')
# ----> 2 imputer.fit_transform(ts[ts.segments[0]]).plot()
#
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/transforms/base.py in ?(self, ts)
#     142         -------
#     143         :
#     144             Transformed TSDataset.
#     145         """
# --> 146         return self.fit(ts=ts).transform(ts=ts)
#
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/transforms/base.py in ?(self, ts)
#      86         -------
#      87         :
#      88             The fitted transform instance.
#      89         """
# ---> 90         df = ts.to_pandas(flatten=False, features=self.required_features)
#      91         self._fit(df=df)
#      92         return self
#
# /home/user/conda/envs/algo/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_pandas'

# %%
ts.plot(segments=["2023"])

# %% [markdown]
# ### 2. How to run a validation <a class="anchor" id="chapter2"></a>

# %% [markdown]
# For an easy start let's create a Prophet model

# %%
horizon = 31  # Set the horizon for predictions
model = ProphetModel()  # Create a model
transforms = [TimeSeriesImputerTransform(strategy='seasonal')]  # A list of transforms -  we will not use any of them

# %% [markdown]
# ### `Pipeline` <a class="anchor" id="section_2_1"></a>

# %% [markdown]
# Now let's create an instance of `Pipeline`.

# %%
pipeline = Pipeline(model=model, transforms=transforms, horizon=horizon)

# %% [markdown]
# We are going to run `backtest` method for it. As a result, three dataframes will be returned:
# * dataframe with metrics for each fold and each segment,
# * dataframe with predictions,
# * dataframe with information about folds.

# %%
metrics_df, forecast_df, fold_info_df = pipeline.backtest(ts=ts, metrics=[MAE(), MSE(), SMAPE()])
# Out:
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/models/prophet.py:108: UserWarning: This model doesn't work with exogenous features unknown in future. Columns ['close', 'high', 'low', 'open', 'value', 'volume'] won't be used.
#   warnings.warn(
# 00:41:57 - cmdstanpy - INFO - Chain [1] start processing
# 00:41:58 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    4.4s
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:432: UserWarning: Segments contains NaNs in the last timestamps.Some of the transforms might work incorrectly or even fail.Make sure that you use the imputer before making the forecast.
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/models/prophet.py:108: UserWarning: This model doesn't work with exogenous features unknown in future. Columns ['close', 'high', 'low', 'open', 'value', 'volume'] won't be used.
#   warnings.warn(
# 00:42:01 - cmdstanpy - INFO - Chain [1] start processing
# 00:42:02 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    8.9s
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:432: UserWarning: Segments contains NaNs in the last timestamps.Some of the transforms might work incorrectly or even fail.Make sure that you use the imputer before making the forecast.
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/models/prophet.py:108: UserWarning: This model doesn't work with exogenous features unknown in future. Columns ['close', 'high', 'low', 'open', 'value', 'volume'] won't be used.
#   warnings.warn(
# 00:42:06 - cmdstanpy - INFO - Chain [1] start processing
# 00:42:07 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:   13.5s
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/models/prophet.py:108: UserWarning: This model doesn't work with exogenous features unknown in future. Columns ['close', 'high', 'low', 'open', 'value', 'volume'] won't be used.
#   warnings.warn(
# 00:42:10 - cmdstanpy - INFO - Chain [1] start processing
# 00:42:12 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:   18.1s
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/models/prophet.py:108: UserWarning: This model doesn't work with exogenous features unknown in future. Columns ['close', 'high', 'low', 'open', 'value', 'volume'] won't be used.
#   warnings.warn(
# 00:42:15 - cmdstanpy - INFO - Chain [1] start processing
# 00:42:16 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:   22.8s
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:282: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   future_dates = pd.date_range(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    3.1s
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:432: UserWarning: Segments contains NaNs in the last timestamps.Some of the transforms might work incorrectly or even fail.Make sure that you use the imputer before making the forecast.
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:282: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   future_dates = pd.date_range(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    6.3s
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:432: UserWarning: Segments contains NaNs in the last timestamps.Some of the transforms might work incorrectly or even fail.Make sure that you use the imputer before making the forecast.
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:282: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   future_dates = pd.date_range(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    9.5s
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:282: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   future_dates = pd.date_range(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:   12.7s
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:282: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   future_dates = pd.date_range(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:   16.0s
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/datasets/tsdataset.py:147: UserWarning: You probably set wrong freq. Discovered freq in you data is 10T, you set 10 min
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   0 tasks      | elapsed:    0.3s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/jovyan/vzaigraev/Moex_contest/time_series/etna/backtest.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22666f63757365642d686f66737461647465725f317841313030227d/home/jovyan/vzaigraev/Moex_contest/time_series/etna/backtest.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> metrics_df, forecast_df, fold_info_df = pipeline.backtest(ts=ts, metrics=[MAE(), MSE(), SMAPE()])
#
# File /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/pipeline/base.py:978, in BasePipeline.backtest(self, ts, metrics, n_folds, mode, aggregate_metrics, n_jobs, refit, stride, joblib_params, forecast_params)
#     976 self._validate_backtest_metrics(metrics=metrics)
#     977 masks = self._prepare_fold_masks(ts=ts, masks=n_folds, mode=mode_enum, stride=stride)
# --> 978 self._folds = self._run_all_folds(
#     979     masks=masks,
#     980     ts=ts,
#     981     metrics=metrics,
#     982     n_jobs=n_jobs,
#     983     refit=refit,
#     984     joblib_params=joblib_params,
#     985     forecast_params=forecast_params,
#     986 )
#     988 metrics_df = self._get_backtest_metrics(aggregate_metrics=aggregate_metrics)
#     989 forecast_df = self._get_backtest_forecasts()
#
# File /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/pipeline/base.py:883, in BasePipeline._run_all_folds(self, masks, ts, metrics, n_jobs, refit, joblib_params, forecast_params)
#     871     fold_process_train_datasets = (
#     872         train for train, _ in self._generate_folds_datasets(ts=ts, masks=fit_masks, horizon=self.horizon)
#     873     )
#     874     fold_process_test_datasets = (
#     875         (
#     876             test
#    (...)
#     881         for group_forecast_masks in forecast_masks
#     882     )
# --> 883     fold_results_flat = parallel(
#     884         delayed(self._process_fold_forecast)(
#     885             forecast=forecasts_flat[group_idx * refit + idx],
#     886             train=train,
#     887             test=test,
#     888             pipeline=pipelines[group_idx],
#     889             fold_number=fold_groups[group_idx]["forecast_fold_numbers"][idx],
#     890             mask=fold_groups[group_idx]["forecast_masks"][idx],
#     891             metrics=metrics,
#     892         )
#     893         for group_idx, (train, group_fold_process_test_datasets) in enumerate(
#     894             zip(fold_process_train_datasets, fold_process_test_datasets)
#     895         )
#     896         for idx, test in enumerate(group_fold_process_test_datasets)
#     897     )
#     899 results = {
#     900     fold_number: fold_results_flat[group_idx * refit + idx]
#     901     for group_idx in range(len(fold_groups))
#     902     for idx, fold_number in enumerate(fold_groups[group_idx]["forecast_fold_numbers"])
#     903 }
#     904 return results
#
# File /home/user/conda/envs/algo/lib/python3.10/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File /home/user/conda/envs/algo/lib/python3.10/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/pipeline/base.py:726, in BasePipeline._process_fold_forecast(self, forecast, train, test, pipeline, fold_number, mask, metrics)
#     723 test.df = test.df.loc[mask.target_timestamps]
#     725 fold["forecast"] = forecast
# --> 726 fold["metrics"] = deepcopy(pipeline._compute_metrics(metrics=metrics, y_true=test, y_pred=forecast))
#     728 tslogger.log_backtest_run(pd.DataFrame(fold["metrics"]), forecast.to_pandas(), test.to_pandas())
#     729 tslogger.finish_experiment()
#
# File /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/pipeline/base.py:679, in BasePipeline._compute_metrics(self, metrics, y_true, y_pred)
#     677 metrics_values: Dict[str, Dict[str, float]] = {}
#     678 for metric in metrics:
# --> 679     metrics_values[metric.name] = metric(y_true=y_true, y_pred=y_pred)  # type: ignore
#     680 return metrics_values
#
# File /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/metrics/base.py:318, in Metric.__call__(self, y_true, y_pred)
#     316 self._validate_target_columns(y_true=y_true, y_pred=y_pred)
#     317 self._validate_index(y_true=y_true, y_pred=y_pred)
# --> 318 self._validate_nans(y_true=y_true, y_pred=y_pred)
#     320 df_true = y_true[:, :, "target"].sort_index(axis=1)
#     321 df_pred = y_pred[:, :, "target"].sort_index(axis=1)
#
# File /home/user/conda/envs/algo/lib/python3.10/site-packages/etna/metrics/base.py:254, in Metric._validate_nans(y_true, y_pred)
#     252 df_true_isna = df_true.isna().any().any()
#     253 if df_true_isna > 0:
# --> 254     raise ValueError("There are NaNs in y_true")
#     256 df_pred_isna = df_pred.isna().any().any()
#     257 if df_pred_isna > 0:
#
# ValueError: There are NaNs in y_true

# %%
metrics_df.head()
# Out:
#      segment        MAE          MSE     SMAPE  fold_number
# 0  segment_a  18.851344   595.763719  4.372066            0
# 0  segment_a  21.026910   673.249070  4.842875            1
# 0  segment_a  30.107632  1315.679297  6.302994            2
# 0  segment_a  36.204963  2021.144120  7.470983            3
# 0  segment_a  32.003925  1872.618930  6.470948            4

# %%
forecast_df.head()
# Out:
# segment      segment_a
# feature    fold_number      target
# timestamp
# 2019-06-29           0  395.286255
# 2019-06-30           0  386.204016
# 2019-07-01           0  493.164874
# 2019-07-02           0  509.586239
# 2019-07-03           0  497.749328

# %%
fold_info_df.head()
# Out:
#   train_start_time train_end_time test_start_time test_end_time  fold_number
# 0       2019-01-01     2019-06-28      2019-06-29    2019-07-29            0
# 0       2019-01-01     2019-07-29      2019-07-30    2019-08-29            1
# 0       2019-01-01     2019-08-29      2019-08-30    2019-09-29            2
# 0       2019-01-01     2019-09-29      2019-09-30    2019-10-30            3
# 0       2019-01-01     2019-10-30      2019-10-31    2019-11-30            4

# %% [markdown]
# You can additionally get the metrics averaged over folds:

# %%
metrics_df, forecast_df, fold_info_df = pipeline.backtest(
    ts=ts, metrics=[MAE(), MSE(), SMAPE()], aggregate_metrics=True
)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 14:35:20 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:20 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# 14:35:21 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:21 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.9s remaining:    0.0s
# 14:35:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:22 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.9s remaining:    0.0s
# 14:35:23 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:23 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    4.0s remaining:    0.0s
# 14:35:24 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:24 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.0s finished

# %%
metrics_df.head()
# Out:
#      segment        MAE          MSE     SMAPE
# 0  segment_a  27.638955  1295.691027  5.891973

# %%
forecast_df.head()
# Out:
# segment      segment_a
# feature    fold_number      target
# timestamp
# 2019-06-29           0  395.286255
# 2019-06-30           0  386.204016
# 2019-07-01           0  493.164874
# 2019-07-02           0  509.586239
# 2019-07-03           0  497.749328

# %%
fold_info_df.head()
# Out:
#   train_start_time train_end_time test_start_time test_end_time  fold_number
# 0       2019-01-01     2019-06-28      2019-06-29    2019-07-29            0
# 0       2019-01-01     2019-07-29      2019-07-30    2019-08-29            1
# 0       2019-01-01     2019-08-29      2019-08-30    2019-09-29            2
# 0       2019-01-01     2019-09-29      2019-09-30    2019-10-30            3
# 0       2019-01-01     2019-10-30      2019-10-31    2019-11-30            4

# %% [markdown]
# ### 3. Backtest with fold masks<a class="anchor" id="chapter3"></a>

# %% [markdown]
# You can use your backtest strategies using `FoldMask`. In order to make a `FoldMask`, you need to specify `first_train_timestamp`, `last_train_timestamp`, `target_timestamps`. Then you need to pass a list of masks as the `n_folds` parameter to the `pipeline.backtest`.
#
# Consider 3 strategies similar to `SlidingWindowSplitter`, `ExpandingWindowSplitter` and `SingleWindowSplitter` from `sktime`.

# %% [markdown]
# #### `ExpandingWindowSplitter`
#
# For this backtest strategy you can use our backtest with `mode="expand"`.

# %%
metrics_df, _, _ = pipeline.backtest(ts=ts, metrics=[MAE(), MSE(), SMAPE()], n_folds=3, mode="expand")
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 14:35:30 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:30 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# 14:35:31 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:31 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.0s remaining:    0.0s
# 14:35:32 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:32 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.0s finished

# %%
metrics_df
# Out:
#      segment        MAE          MSE     SMAPE  fold_number
# 0  segment_a  30.107632  1315.679297  6.302994            0
# 0  segment_a  36.204963  2021.144120  7.470983            1
# 0  segment_a  32.003925  1872.618930  6.470948            2

# %% [markdown]
# #### `SingleWindowSplitter`

# %% [markdown]
# For this backtest strategy you can use our backtest with parameter `n_folds=1` or if you need specific window from your dataset you can create a mask with `FoldMask`.

# %%
from etna.pipeline import FoldMask
import numpy as np

# %%
# 1 Without mask

metrics_df, _, _ = pipeline.backtest(ts=ts, metrics=[MAE(), MSE(), SMAPE()], n_folds=1)
metrics_df
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 14:35:33 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:33 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
#      segment        MAE         MSE     SMAPE  fold_number
# 0  segment_a  32.003925  1872.61893  6.470948            0

# %%
# 2 With specific mask
window_size = 85
first_train_timestamp = ts.index.min() + np.timedelta64(100, "D")
last_train_timestamp = first_train_timestamp + np.timedelta64(window_size, "D")
target_timestamps = pd.date_range(start=last_train_timestamp + np.timedelta64(1, "D"), periods=horizon)
mask = FoldMask(
    first_train_timestamp=first_train_timestamp,
    last_train_timestamp=last_train_timestamp,
    target_timestamps=target_timestamps,
)

# %%
# 1 Without mask

metrics_df, _, _ = pipeline.backtest(ts=ts, metrics=[MAE(), MSE(), SMAPE()], n_folds=[mask])
metrics_df
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 14:35:34 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:35 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s finished
#      segment        MAE          MSE     SMAPE  fold_number
# 0  segment_a  39.782294  2191.914485  9.056343            0

# %% [markdown]
# #### `SlidingWindowSplitter`

# %% [markdown]
# To implement this backtest strategy you need to create a list of fold masks with `FoldMask`.

# %%
n_folds = 3

# %%
def sliding_window_masks(window_size, n_folds):
    masks = []
    for n in range(n_folds):
        first_train_timestamp = ts.index.min() + np.timedelta64(100, "D") + np.timedelta64(n, "D")
        last_train_timestamp = first_train_timestamp + np.timedelta64(window_size, "D")
        target_timestamps = pd.date_range(start=last_train_timestamp + np.timedelta64(1, "D"), periods=horizon)
        mask = FoldMask(
            first_train_timestamp=first_train_timestamp,
            last_train_timestamp=last_train_timestamp,
            target_timestamps=target_timestamps,
        )
        masks.append(mask)
    return masks

# %%
masks = sliding_window_masks(window_size=window_size, n_folds=n_folds)
metrics_df, _, _ = pipeline.backtest(ts=ts, metrics=[MAE(), MSE(), SMAPE()], n_folds=masks)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 14:35:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:36 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# 14:35:37 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:37 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.4s remaining:    0.0s
# 14:35:38 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:38 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.6s finished

# %%
metrics_df
# Out:
#      segment        MAE          MSE     SMAPE  fold_number
# 0  segment_a  39.782294  2191.914485  9.056343            0
# 0  segment_a  40.293273  2287.327210  9.108208            1
# 0  segment_a  39.861473  2192.540812  9.010115            2

# %% [markdown]
# ### 4. Validation visualisation <a class="anchor" id="chapter4"></a>

# %%
plot_backtest(forecast_df, ts)

# %% [markdown]
# To visualize the train part, you can specify the `history_len` parameter.

# %%
plot_backtest(forecast_df, ts, history_len=70)

# %% [markdown]
# ### 5. Metrics visualization  <a class="anchor" id="chapter5"></a>

# %% [markdown]
# In this section we will analyze the backtest results from the different point of views.

# %%
from etna.analysis import (
    metric_per_segment_distribution_plot,
    plot_residuals,
    plot_metric_per_segment,
    prediction_actual_scatter_plot,
)

# %%
df = pd.read_csv("./data/example_dataset.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = TSDataset.to_dataset(df)
ts_all = TSDataset(df, freq="D")

# %%
metrics_df, forecast_df, fold_info_df = pipeline.backtest(ts=ts_all, metrics=[MAE(), MSE(), SMAPE()])
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 14:35:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:42 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:42 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:42 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:42 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.8s remaining:    0.0s
# 14:35:46 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:46 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:46 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:46 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:46 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:46 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:46 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:46 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    7.6s remaining:    0.0s
# 14:35:49 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:50 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:50 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:50 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:50 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   11.4s remaining:    0.0s
# 14:35:53 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:53 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:53 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:53 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:53 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:53 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:53 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:53 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   15.3s remaining:    0.0s
# 14:35:57 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:57 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:57 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:57 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:57 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:57 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:57 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:57 - cmdstanpy - INFO - Chain [1] done processing
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   19.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   19.1s finished

# %% [markdown]
# Let's look at the distribution of the SMAPE metric by folds. You can set `type_plot` as `box`, `violin` or `hist`.

# %%
metric_per_segment_distribution_plot(metrics_df=metrics_df, metric_name="SMAPE", plot_type="box")

# %% [markdown]
# Let's look at the SMAPE metric by segments

# %%
plot_metric_per_segment(metrics_df=metrics_df, metric_name="SMAPE", ascending=True)

# %% [markdown]
# Now let's look at the residuals of the model predictions from the backtest. Analysis of the residuals can help establish a dependency in the data that our model was not able to find. This way we can add features or improve the model or make sure that there is no dependency in the residuals. Also, you can visualize the residuals not only by timestamp but by any feature.

# %%
plot_residuals(forecast_df=forecast_df, ts=ts_all)

# %%
prediction_actual_scatter_plot(forecast_df=forecast_df, ts=ts_all)

# %% [markdown]
# That's all for this notebook. More features you can find in our documentation!

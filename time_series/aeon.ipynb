# %%
pip install -U aeon[all_extras]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 MB 7.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 32.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 21.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 6.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 5.8 MB/s eta 0:00:0000:0100:01mm
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 KB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 12.6 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 KB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 15.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 KB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 5.0 MB/s eta 0:00:00
# ...

# %%
from aeon.forecasting.trend import TrendForecaster
import numpy as np
from utils import CompanyStats

# %%
stats = CompanyStats()

candles = stats.get_candles(dates=('2023-12-07', '2023-12-07'))
candles.set_index('begin', inplace=True)
# candles = candles.asfreq('1h')
candles.index
# Out:
# DatetimeIndex(['2023-12-07 09:50:00', '2023-12-07 10:00:00',
#                '2023-12-07 10:10:00', '2023-12-07 10:20:00',
#                '2023-12-07 10:30:00', '2023-12-07 10:40:00',
#                '2023-12-07 10:50:00', '2023-12-07 11:00:00',
#                '2023-12-07 11:10:00', '2023-12-07 11:20:00',
#                '2023-12-07 11:30:00', '2023-12-07 11:40:00',
#                '2023-12-07 11:50:00', '2023-12-07 12:00:00',
#                '2023-12-07 12:10:00', '2023-12-07 12:20:00',
#                '2023-12-07 12:30:00', '2023-12-07 12:40:00',
#                '2023-12-07 12:50:00', '2023-12-07 13:00:00',
#                '2023-12-07 13:10:00', '2023-12-07 13:20:00',
#                '2023-12-07 13:30:00', '2023-12-07 13:40:00',
#                '2023-12-07 13:50:00', '2023-12-07 14:00:00',
#                '2023-12-07 14:10:00', '2023-12-07 14:20:00',
#                '2023-12-07 14:30:00', '2023-12-07 14:40:00',
# ...

# %%
candles
# Out:
#                        open   close    high     low        value     volume
# begin
# 2023-12-07 09:50:00  267.62  267.62  267.62  267.62   14703042.8    54940.0
# 2023-12-07 10:00:00  267.74  268.44  269.39  267.52  946363166.5  3525290.0
# 2023-12-07 10:10:00  268.44  269.76  270.19  268.36  896466106.5  3324320.0
# 2023-12-07 10:20:00  269.77  269.39  270.37  269.20  463233190.0  1716300.0
# 2023-12-07 10:30:00  269.40  270.12  270.44  269.40  384171284.7  1422260.0
# ...                     ...     ...     ...     ...          ...        ...
# 2023-12-07 23:00:00  265.17  265.21  265.45  265.10   23583896.4    88950.0
# 2023-12-07 23:10:00  265.22  265.01  265.27  265.01   16541232.0    62400.0
# 2023-12-07 23:20:00  265.10  265.17  265.38  265.00   22928346.6    86490.0
# 2023-12-07 23:30:00  265.15  265.13  265.21  265.03   11441749.6    43160.0
# 2023-12-07 23:40:00  265.13  265.12  265.19  265.04   38834186.7   146480.0
#
# [83 rows x 6 columns]

# %%
candles[candles.isna()]
# Out:
#                      open  close  high  low  value  volume
# begin
# 2023-12-07 09:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 10:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 11:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 12:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 13:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 14:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 15:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 16:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 17:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 18:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 19:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 20:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 21:50:00   NaN    NaN   NaN  NaN    NaN     NaN
# 2023-12-07 22:50:00   NaN    NaN   NaN  NaN    NaN     NaN

# %%
candles.head()
# Out:
#                        open   close    high     low        value     volume
# begin
# 2023-12-07 09:50:00  267.62  267.62  267.62  267.62   14703042.8    54940.0
# 2023-12-07 10:00:00  267.74  268.44  269.39  267.52  946363166.5  3525290.0
# 2023-12-07 10:10:00  268.44  269.76  270.19  268.36  896466106.5  3324320.0
# 2023-12-07 10:20:00  269.77  269.39  270.37  269.20  463233190.0  1716300.0
# 2023-12-07 10:30:00  269.40  270.12  270.44  269.40  384171284.7  1422260.0

# %%
forecaster = TrendForecaster()
X = candles.drop(columns=['close'])
y = candles['close']
forecaster.fit(X=X, y=y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/jovyan/vzaigraev/Moex_contest/time_series/aeon.ipynb Cell 5 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22666f63757365642d686f66737461647465725f317841313030227d/home/jovyan/vzaigraev/Moex_contest/time_series/aeon.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> X = candles.drop(columns=['close'])
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22666f63757365642d686f66737461647465725f317841313030227d/home/jovyan/vzaigraev/Moex_contest/time_series/aeon.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> y = candles['close']
# ...

# %%
forecaster.predict(fh=[1,2], X = X)
# Out:
# /home/user/conda/envs/algo/lib/python3.10/site-packages/aeon/forecasting/base/_fh.py:812: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version.
#   freq = x.freq
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/jovyan/vzaigraev/Moex_contest/time_series/aeon.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22666f63757365642d686f66737461647465725f317841313030227d/home/jovyan/vzaigraev/Moex_contest/time_series/aeon.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> forecaster.predict(fh=[1,2], X = X)
#
# File /home/user/conda/envs/algo/lib/python3.10/site-packages/aeon/forecasting/base/_base.py:403, in BaseForecaster.predict(self, fh, X)
#     401 # we call the ordinary _predict if no looping/vectorization needed
#     402 if not self._is_vectorized:
# ...
